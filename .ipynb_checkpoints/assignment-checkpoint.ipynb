# %%
# !pip install pydriller pandas duckdb
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 26.0.1 is available.
# You should consider upgrading via the '/Users/Study/development/venv/bin/python3 -m pip install --upgrade pip' command.

# %%
from pydriller import Repository...
# Out:
#   Cell In[2], line 1
#     from pydriller import Repository...
#                                     ^
# SyntaxError: invalid syntax

# %%
from pydriller import Repository

# %%
repo_url = "https://github.com/karsh-404/DSSE-assignment.git"

# %% [markdown]
# We used PyDriller to extract commit history.
#
# Data was stored using pandas.
#
# Analysis shows top contributors and commit trends.
#
# Results exported to CSV.
